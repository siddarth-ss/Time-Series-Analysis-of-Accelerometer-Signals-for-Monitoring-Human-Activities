# %% [markdown]
# # Creating directories to store csv files for 15 different
#
# ---

# %%
# Creating 15 directories to store individual files corresponding to each subject.

# The 4 files for climbing_down, climbing_up, running and walking needs to be uploaded for
# each subject in their respective folder
# !mkdir subject1
# !mkdir subject2
# !mkdir subject3
# !mkdir subject4
# !mkdir subject5
# !mkdir subject6
# !mkdir subject7
# !mkdir subject8
# !mkdir subject9
# !mkdir subject10
# !mkdir subject11
# !mkdir subject12
# !mkdir subject13
# !mkdir subject14
# !mkdir subject15

# %% [markdown]
# # Load 4 files for Subject 1

# %%
# %cd /content/subject1/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 2

# %%
# %cd /content/subject2/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 3

# %%
# %cd /content/subject3/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 4

# %%
# %cd /content/subject4/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 5

# %%
# %cd /content/subject5/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 6

# %%
# %cd /content/subject6/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 7

# %%
# %cd /content/subject7/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 8

# %%
# %cd /content/subject8/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 9

# %%
# %cd /content/subject9/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 10

# %%
# %cd /content/subject10/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 11

# %%
# %cd /content/subject11/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 12

# %%
# %cd /content/subject12/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 13

# %%
# %cd /content/subject13/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 14

# %%
# %cd /content/subject14/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Load 4 files for Subject 15

# %%
# %cd /content/subject15/
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # Importing all the csv files into Dataframes

# %%
import pandas as pd

#Importing all the 15*4 = 60 files into data frames

sub1_climbingdown = pd.read_csv('/content/subject1/acc_climbingdown_chest.csv')
sub1_climbingup = pd.read_csv('/content/subject1/acc_climbingup_chest.csv')
sub1_running = pd.read_csv('/content/subject1/acc_running_chest.csv')
sub1_walking = pd.read_csv('/content/subject1/acc_walking_chest.csv')

sub2_climbingdown = pd.read_csv('/content/subject2/acc_climbingdown_chest.csv')
sub2_climbingup = pd.read_csv('/content/subject2/acc_climbingup_chest.csv')
sub2_running = pd.read_csv('/content/subject2/acc_running_chest.csv')
sub2_walking = pd.read_csv('/content/subject2/acc_walking_chest.csv')

sub3_climbingdown = pd.read_csv('/content/subject3/acc_climbingdown_chest.csv')
sub3_climbingup = pd.read_csv('/content/subject3/acc_climbingup_chest.csv')
sub3_running = pd.read_csv('/content/subject3/acc_running_chest.csv')
sub3_walking = pd.read_csv('/content/subject3/acc_walking_chest.csv')

sub4_climbingdown = pd.read_csv('/content/subject4/acc_climbingdown_chest.csv')
sub4_climbingup = pd.read_csv('/content/subject4/acc_climbingup_chest.csv')
sub4_running = pd.read_csv('/content/subject4/acc_running_chest.csv')
sub4_walking = pd.read_csv('/content/subject4/acc_walking_2_chest.csv')

sub5_climbingdown = pd.read_csv('/content/subject5/acc_climbingdown_chest.csv')
sub5_climbingup = pd.read_csv('/content/subject5/acc_climbingup_chest.csv')
sub5_running = pd.read_csv('/content/subject5/acc_running_chest.csv')
sub5_walking = pd.read_csv('/content/subject5/acc_walking_chest.csv')

sub6_climbingdown = pd.read_csv('/content/subject6/acc_climbingdown_chest.csv')
sub6_climbingup = pd.read_csv('/content/subject6/acc_climbingup_chest.csv')
sub6_running = pd.read_csv('/content/subject6/acc_running_chest.csv')
sub6_walking = pd.read_csv('/content/subject6/acc_walking_chest.csv')

sub7_climbingdown = pd.read_csv('/content/subject7/acc_climbingdown_chest.csv')
sub7_climbingup = pd.read_csv('/content/subject7/acc_climbingup_chest.csv')
sub7_running = pd.read_csv('/content/subject7/acc_running_chest.csv')
sub7_walking = pd.read_csv('/content/subject7/acc_walking_chest.csv')

sub8_climbingdown = pd.read_csv('/content/subject8/acc_climbingdown_chest.csv')
sub8_climbingup = pd.read_csv('/content/subject8/acc_climbingup_chest.csv')
sub8_running = pd.read_csv('/content/subject8/acc_running_chest.csv')
sub8_walking = pd.read_csv('/content/subject8/acc_walking_chest.csv')

sub9_climbingdown = pd.read_csv('/content/subject9/acc_climbingdown_chest.csv')
sub9_climbingup = pd.read_csv('/content/subject9/acc_climbingup_chest.csv')
sub9_running = pd.read_csv('/content/subject9/acc_running_chest.csv')
sub9_walking = pd.read_csv('/content/subject9/acc_walking_chest.csv')

sub10_climbingdown = pd.read_csv('/content/subject10/acc_climbingdown_chest.csv')
sub10_climbingup = pd.read_csv('/content/subject10/acc_climbingup_chest.csv')
sub10_running = pd.read_csv('/content/subject10/acc_running_chest.csv')
sub10_walking = pd.read_csv('/content/subject10/acc_walking_chest.csv')

sub11_climbingdown = pd.read_csv('/content/subject11/acc_climbingdown_chest.csv')
sub11_climbingup = pd.read_csv('/content/subject11/acc_climbingup_chest.csv')
sub11_running = pd.read_csv('/content/subject11/acc_running_chest.csv')
sub11_walking = pd.read_csv('/content/subject11/acc_walking_chest.csv')

sub12_climbingdown = pd.read_csv('/content/subject12/acc_climbingdown_chest.csv')
sub12_climbingup = pd.read_csv('/content/subject12/acc_climbingup_chest.csv')
sub12_running = pd.read_csv('/content/subject12/acc_running_chest.csv')
sub12_walking = pd.read_csv('/content/subject12/acc_walking_chest.csv')

sub13_climbingdown = pd.read_csv('/content/subject13/acc_climbingdown_chest.csv')
sub13_climbingup = pd.read_csv('/content/subject13/acc_climbingup_chest.csv')
sub13_running = pd.read_csv('/content/subject13/acc_running_chest.csv')
sub13_walking = pd.read_csv('/content/subject13/acc_walking_2_chest.csv')

sub14_climbingdown = pd.read_csv('/content/subject14/acc_climbingdown_chest.csv')
sub14_climbingup = pd.read_csv('/content/subject14/acc_climbingup_chest.csv')
sub14_running = pd.read_csv('/content/subject14/acc_running_chest.csv')
sub14_walking = pd.read_csv('/content/subject14/acc_walking_chest.csv')

sub15_climbingdown = pd.read_csv('/content/subject15/acc_climbingdown_chest.csv')
sub15_climbingup = pd.read_csv('/content/subject15/acc_climbingup_chest.csv')
sub15_running = pd.read_csv('/content/subject15/acc_running_chest.csv')
sub15_walking = pd.read_csv('/content/subject15/acc_walking_chest.csv')

# %%
# Storing all the 60 data frames into their respectively created lists

climbingdown = [sub1_climbingdown, sub2_climbingdown, sub3_climbingdown, sub4_climbingdown, sub5_climbingdown,
                sub6_climbingdown, sub7_climbingdown, sub8_climbingdown, sub9_climbingdown, sub10_climbingdown,
                sub11_climbingdown, sub12_climbingdown, sub13_climbingdown, sub14_climbingdown, sub15_climbingdown]

climbingup = [sub1_climbingup, sub2_climbingup, sub3_climbingup, sub4_climbingup, sub5_climbingup, sub6_climbingup,
              sub7_climbingup, sub8_climbingup, sub9_climbingup, sub10_climbingup, sub11_climbingup, sub12_climbingup,
              sub13_climbingup, sub14_climbingup, sub15_climbingup]

walking = [sub1_walking, sub2_walking, sub3_walking, sub4_walking, sub5_walking, sub6_walking, sub7_walking,
           sub8_walking, sub9_walking, sub10_walking, sub11_walking, sub12_walking, sub13_walking, sub14_walking,
           sub15_walking]

running = [sub1_running, sub2_running, sub3_running, sub4_running, sub5_running, sub6_running, sub7_running,
           sub8_running, sub9_running, sub10_running, sub11_running, sub12_running, sub13_running, sub14_running,
           sub15_running]

# %% [markdown]
# # Installing Required Packages for Creating Visibility Graphs

# %%
# !pip install ts2vg
# !pip install igraph

# %% [markdown]
# # Natural Visibility Graph and corresponding Average degree, Network_diameter, and Average_path_length
#
# Includes 4 parts - Tasks 1.1 to 1.4
# - Applying natural visibility graph (NVG)
# - Computing average degree, network diameter, and average path length
# - Selecting sample size of 1024 data points for each of the 15 time series
# - Tabulating all the results for NVG

# %%
from statistics import mean
from ts2vg import NaturalVG

# Creating an empty data frame for NVG to store the final tablular result
column_names = ["Method", "Subject", "Accelerometer_axis", "Average_degree", "Network_diameter",
                "Average_path_length", "Activity"]
natural_g = pd.DataFrame(columns = column_names)

# Creating a list of accelerometer axis to iterate through the loop
axes = ['attr_x', 'attr_y', 'attr_z']

for i in range (1,16):
  for a in axes:

    # Storing the axis values as 'x', 'y', 'z' based on the the value of loop iterator
    if a == 'attr_x':
      acc_axis = 'x'
    elif a == 'attr_y':
      acc_axis = 'y'
    elif a == 'attr_z':
      acc_axis = 'z'

    # Climbing Down - Applying NVG
    g_climbingdown = NaturalVG()
    g_climbingdown.build(climbingdown[i-1][a][1000:2024])
    ig_climbingdown = g_climbingdown.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    natural_g = natural_g.append({"Method" : "NVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_climbingdown.degree()),
                                "Network_diameter" : ig_climbingdown.diameter(),
                                "Average_path_length" : ig_climbingdown.average_path_length(),
                                "Activity" : "Climbing Down"}, ignore_index=True)

    # Climbing Up - Applying NVG
    g_climbingup = NaturalVG()
    g_climbingup.build(climbingup[i-1][a][1000:2024])
    ig_climbingup = g_climbingup.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    natural_g = natural_g.append({"Method" : "NVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_climbingup.degree()),
                                "Network_diameter" : ig_climbingup.diameter(),
                                "Average_path_length" : ig_climbingup.average_path_length(),
                                "Activity" : "Climbing Up"}, ignore_index=True)
    
    # Walking - Applying NVG
    g_walking = NaturalVG()
    g_walking.build(walking[i-1][a][1000:2024])
    ig_walking = g_walking.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    natural_g = natural_g.append({"Method" : "NVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_walking.degree()),
                                "Network_diameter" : ig_walking.diameter(),
                                "Average_path_length" : ig_walking.average_path_length(),
                                "Activity" : "Walking"}, ignore_index=True)
    
    # Running - Applying NVG
    g_running = NaturalVG()
    g_running.build(running[i-1][a][1000:2024])
    ig_running = g_running.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    natural_g = natural_g.append({"Method" : "NVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_running.degree()),
                                "Network_diameter" : ig_running.diameter(),
                                "Average_path_length" : ig_running.average_path_length(),
                                "Activity" : "Running"}, ignore_index=True)

# %% [markdown]
# # Natural Visibility Graph Tabular Data

# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()
natural_g
# Out:
#     Method Subject  ... Average_path_length       Activity
# 0      NVG       1  ...            6.598815  Climbing Down
# 1      NVG       1  ...            3.882824    Climbing Up
# 2      NVG       1  ...            4.441492        Walking
# 3      NVG       1  ...            4.307645        Running
# 4      NVG       1  ...            4.261784  Climbing Down
# ..     ...     ...  ...                 ...            ...
# 175    NVG      15  ...           57.067139        Running
# 176    NVG      15  ...            4.692059  Climbing Down
# 177    NVG      15  ...            4.766421    Climbing Up
# 178    NVG      15  ...            4.945985        Walking
# 179    NVG      15  ...            4.651544        Running
#
# [180 rows x 7 columns]

# %% [markdown]
# # Horizontal Visibility Graph and corresponding Average degree, Network_diameter, and Average_path_length
#
# Includes 4 parts - Tasks 1.1 to 1.4
# - Applying horizontal visibility graph (HVG)
# - Computing average degree, network diameter, and average path length
# - Selecting sample size of 1024 data points for each of the 15 time series
# - Tabulating all the results for HVG

# %%
from statistics import mean
from ts2vg import HorizontalVG

# Creating an empty data frame for HVG to store the final tablular result
column_names = ["Method", "Subject", "Accelerometer_axis", "Average_degree", "Network_diameter",
                "Average_path_length", "Activity"]
horizontal_g = pd.DataFrame(columns = column_names)

# Creating a list of accelerometer axis to iterate through the loop
axes = ['attr_x', 'attr_y', 'attr_z']

for i in range (1,16):
  for a in axes:

    # Storing the axis values as 'x', 'y', 'z' based on the the value of loop iterator
    if a == 'attr_x':
      acc_axis = 'x'
    elif a == 'attr_y':
      acc_axis = 'y'
    elif a == 'attr_z':
      acc_axis = 'z'
    
    # Climbing Down - Applying HVG
    g_climbingdown = HorizontalVG()
    g_climbingdown.build(climbingdown[i-1][a][1000:2024])
    ig_climbingdown = g_climbingdown.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    horizontal_g = horizontal_g.append({"Method" : "HVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_climbingdown.degree()),
                                "Network_diameter" : ig_climbingdown.diameter(),
                                "Average_path_length" : ig_climbingdown.average_path_length(),
                                "Activity" : "Climbing Down"}, ignore_index=True)

    # Climbing Up - Applying HVG  
    g_climbingup = HorizontalVG()
    g_climbingup.build(climbingup[i-1][a][1000:2024])
    ig_climbingup = g_climbingup.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    horizontal_g = horizontal_g.append({"Method" : "HVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_climbingup.degree()),
                                "Network_diameter" : ig_climbingup.diameter(),
                                "Average_path_length" : ig_climbingup.average_path_length(),
                                "Activity" : "Climbing Up"}, ignore_index=True)

    # Walking - Applying HVG  
    g_walking = HorizontalVG()
    g_walking.build(walking[i-1][a][1000:2024])
    ig_walking = g_walking.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    horizontal_g = horizontal_g.append({"Method" : "HVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_walking.degree()),
                                "Network_diameter" : ig_walking.diameter(),
                                "Average_path_length" : ig_walking.average_path_length(),
                                "Activity" : "Walking"}, ignore_index=True)

    # Running - Applying HVG  
    g_running = HorizontalVG()
    g_running.build(running[i-1][a][1000:2024])
    ig_running = g_running.as_igraph()

    # Appending the respective values of average degree and network diameter in the dataframe
    horizontal_g = horizontal_g.append({"Method" : "HVG", "Subject" : i, "Accelerometer_axis" : acc_axis,
                                "Average_degree" : mean(ig_running.degree()),
                                "Network_diameter" : ig_running.diameter(),
                                "Average_path_length" : ig_running.average_path_length(),
                                "Activity" : "Running"}, ignore_index=True)

# %% [markdown]
# # Horizontal Visibility Graph Tabular Data

# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()
horizontal_g
# Out:
#     Method Subject  ... Average_path_length       Activity
# 0      HVG       1  ...           14.510884  Climbing Down
# 1      HVG       1  ...           15.409904    Climbing Up
# 2      HVG       1  ...           11.578024        Walking
# 3      HVG       1  ...            7.543843        Running
# 4      HVG       1  ...           12.518642  Climbing Down
# ..     ...     ...  ...                 ...            ...
# 175    HVG      15  ...           59.485246        Running
# 176    HVG      15  ...           11.783465  Climbing Down
# 177    HVG      15  ...           11.595193    Climbing Up
# 178    HVG      15  ...           10.897949        Walking
# 179    HVG      15  ...            9.290619        Running
#
# [180 rows x 7 columns]

# %% [markdown]
# # Scatter Plots - Average degree v/s Network diameter
# Task 1.5
#
# Includes 6 scatter plots for Average degree v/s Network diameter for activities **walking** and **running**
# -  For each method (HVG and NVG)
# - For each accelerometer signal (X, Y, Z)

# %%
# Importing required libraries for scatter plots
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
# %matplotlib inline

# Creating a list of required activities for generating scatter plot
scatter_list_a = ['Running','Walking']

# Scatter plot for NVG
walking_running_nvg = natural_g[natural_g.Activity.isin(scatter_list_a)]
sns.relplot(data = walking_running_nvg, x = "Average_degree", y = "Network_diameter",
            hue = "Activity", col = "Accelerometer_axis", style = "Method")

# Scatter plot for HVG
walking_running_hvg = horizontal_g[horizontal_g.Activity.isin(scatter_list_a)]
sns.relplot(data = walking_running_hvg, x = "Average_degree", y = "Network_diameter",
            hue = "Activity", col = "Accelerometer_axis", style = "Method")

# %% [markdown]
# # Scatter Plots - Average degree v/s Network diameter
# Task 1.6
#
# Includes 6 scatter plots for Average degree v/s Network diameter for activities **climbing up** and **climbing down**
# -  For each method (HVG and NVG)
# - For each accelerometer signal (X, Y, Z)

# %%
# Importing required libraries for scatter plots
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
# %matplotlib inline

# Creating a list of required activities for generating scatter plot
scatter_list_b = ['Climbing Down','Climbing Up']

# Scatter plot for NVG
climbing_up_down_nvg = natural_g[natural_g.Activity.isin(scatter_list_b)]
sns.relplot(data = climbing_up_down_nvg, x = "Average_degree", y = "Network_diameter",
            hue = "Activity", col = "Accelerometer_axis", style = "Method")

# Scatter plot for HVG
climbing_up_down_hvg = horizontal_g[horizontal_g.Activity.isin(scatter_list_b)]
sns.relplot(data = climbing_up_down_hvg, x = "Average_degree", y = "Network_diameter",
            hue = "Activity", col = "Accelerometer_axis", style = "Method")

# %% [markdown]
# # Functions to calculate ordinal patterns, permutation entropy and complexity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

# %% [markdown]
# # Permutation Entropy and Complexity
#
# Includes parts - Tasks 2.1 & 2.2
# - Calculating permutation entropy and complexity
# - Varying the following parameters:
#   - Embedded Dimension (3, 4, 5, 6)
#   - Embedded Delay (1, 2, 3)
#   - Signal Length (1024, 2048, 4096)
# - Tabulating all the results

# %%
from seaborn import axisgrid
import pandas as pd

# Creating an empty data frame for HVG to store the final tablular result
column_names = ["Subject", "Accelerometer_axis", "Signal_length", "Dimension",
                "Delay", "Permutation_entropy", "Complexity", "Activity"]
entropy_complexity = pd.DataFrame(columns = column_names)

# Creating a list of the parameter that needs to be varied in the loop
sig_len = [1024, 2048, 4096]
dim_op = [3, 4, 5, 6]
delay_op = [1, 2, 3]

for i in range (1,16):
  for j in dim_op:
    for k in delay_op:
      for x in sig_len:
        
        # Climbing Down Ordinal Patterns
        op_climbing_down_x = ordinal_patterns(climbingdown[i-1]['attr_x'][0:x],j,k)
        op_climbing_down_y = ordinal_patterns(climbingdown[i-1]['attr_y'][0:x],j,k)
        op_climbing_down_z = ordinal_patterns(climbingdown[i-1]['attr_z'][0:x],j,k)

        # Climbing Up Ordinal Patterns
        op_climbing_up_x = ordinal_patterns(climbingup[i-1]['attr_x'][0:x],j,k)
        op_climbing_up_y = ordinal_patterns(climbingup[i-1]['attr_y'][0:x],j,k)
        op_climbing_up_z = ordinal_patterns(climbingup[i-1]['attr_z'][0:x],j,k)

        # Running Ordinal Patterns
        op_running_x = ordinal_patterns(running[i-1]['attr_x'][0:x],j,k)
        op_running_y = ordinal_patterns(running[i-1]['attr_y'][0:x],j,k)
        op_running_z = ordinal_patterns(running[i-1]['attr_z'][0:x],j,k)

        # Walking Ordinal Patterns
        op_walking_x = ordinal_patterns(walking[i-1]['attr_x'][0:x],j,k)
        op_walking_y = ordinal_patterns(walking[i-1]['attr_x'][0:x],j,k)
        op_walking_z = ordinal_patterns(walking[i-1]['attr_x'][0:x],j,k)

        # Appending the respective values of average degree and network diameter in the dataframe
        
        #Climbing Down
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "x",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_down_x),
                                "Complexity" : complexity(op_climbing_down_x),
                                "Activity" : "Climbing Down"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "y",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_down_y),
                                "Complexity" : complexity(op_climbing_down_y),
                                "Activity" : "Climbing Down"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "z",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_down_z),
                                "Complexity" : complexity(op_climbing_down_z),
                                "Activity" : "Climbing Down"}, ignore_index=True)
        
        # Climbing Up
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "x",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_up_x),
                                "Complexity" : complexity(op_climbing_up_x),
                                "Activity" : "Climbing Up"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "y",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_up_y),
                                "Complexity" : complexity(op_climbing_up_y),
                                "Activity" : "Climbing Up"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "z",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_climbing_up_z),
                                "Complexity" : complexity(op_climbing_up_z),
                                "Activity" : "Climbing Up"}, ignore_index=True)
        
        # Running
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "x",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_running_x),
                                "Complexity" : complexity(op_running_x),
                                "Activity" : "Running"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "y",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_running_y),
                                "Complexity" : complexity(op_running_y),
                                "Activity" : "Running"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "z",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_running_z),
                                "Complexity" : complexity(op_running_z),
                                "Activity" : "Running"}, ignore_index=True)
        
        # Walking
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "x",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_walking_x),
                                "Complexity" : complexity(op_walking_x),
                                "Activity" : "Walking"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "y",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_walking_y),
                                "Complexity" : complexity(op_walking_y),
                                "Activity" : "Walking"}, ignore_index=True)
        entropy_complexity = entropy_complexity.append({"Subject" : i, "Accelerometer_axis" : "z",
                                "Signal_length" : x,
                                "Dimension" : j,
                                "Delay" : k,
                                "Permutation_entropy" : p_entropy(op_walking_z),
                                "Complexity" : complexity(op_walking_z),
                                "Activity" : "Walking"}, ignore_index=True)

# %% [markdown]
# # Tabular Data of Permutation Entropy and Complexity

# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()
entropy_complexity
# Out:
#      Subject Accelerometer_axis  ... Complexity       Activity
# 0          1                  x  ...   0.113789  Climbing Down
# 1          1                  y  ...   0.109263  Climbing Down
# 2          1                  z  ...   0.112078  Climbing Down
# 3          1                  x  ...   0.089954    Climbing Up
# 4          1                  y  ...   0.122269    Climbing Up
# ...      ...                ...  ...        ...            ...
# 6475      15                  y  ...   0.352555        Running
# 6476      15                  z  ...   0.174448        Running
# 6477      15                  x  ...   0.165445        Walking
# 6478      15                  y  ...   0.165445        Walking
# 6479      15                  z  ...   0.165445        Walking
#
# [6480 rows x 8 columns]

# %% [markdown]
# # Scatter Plots - Permutation Entropy v/s Complexity
# Task 2.3
#
# Includes 12 scatter plots for Permutation Entropy v/s Complexity for activities **walking** and **running**
# - For signal length = 4096 and embedded delay = 1
# - For embedded dimension = 3, 4, 5, 6 and all three accelerometer directions (X, Y, Z)

# %%
# Importing required libraries for scatter plots
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
# %matplotlib inline

# Creating a list of required activities for generating scatter plot
scatter_list_a = ['Running','Walking']

# Subsetting to create a table with signal length 4096 and embedded delay 1
walking_running_perm_comp = entropy_complexity[entropy_complexity.Signal_length == 4096]
walking_running_perm_comp = walking_running_perm_comp[walking_running_perm_comp.Delay == 1]

walking_running_perm_comp = walking_running_perm_comp[walking_running_perm_comp.Activity.isin(scatter_list_a)]

sns.relplot(data = walking_running_perm_comp, x = "Permutation_entropy", y = "Complexity",
            hue = "Activity", col = "Accelerometer_axis", row = "Dimension", style = "Signal_length")

# %% [markdown]
# # Scatter Plots - Permutation Entropy v/s Complexity
# Task 2.4
#
# Includes 12 scatter plots for Permutation Entropy v/s Complexity for activities **climbing up** and **climbing down**
# - For signal length = 4096 and embedded delay = 1
# - For embedded dimension = 3, 4, 5, 6 and all three accelerometer directions (X, Y, Z)

# %%
# Importing required libraries for scatter plots
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
# %matplotlib inline

# Creating a list of required activities for generating scatter plot
scatter_list_b = ['Climbing Down','Climbing Up']

# Subsetting to create a table with signal length 4096 and embedded delay 1
climbing_up_down_perm_comp = entropy_complexity[entropy_complexity.Signal_length == 4096]
climbing_up_down_perm_comp = climbing_up_down_perm_comp[climbing_up_down_perm_comp.Delay == 1]

climbing_up_down_perm_comp = climbing_up_down_perm_comp[climbing_up_down_perm_comp.Activity.isin(scatter_list_b)]

sns.relplot(data = climbing_up_down_perm_comp, x = "Permutation_entropy", y = "Complexity",
            hue = "Activity", col = "Accelerometer_axis", row = "Dimension", style = "Signal_length")
